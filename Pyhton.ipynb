# %%
import copy

a=[1,[2,3]]
b=copy.copy(a)
b[1][1]=10
print(a)
# Out:
# [1, [2, 10]]

# %%
a=257
b=257
print(b)
c=a is b
print(c)
print(id(a))
print(id(b))
# Out:
# 257
# False
# 2873245498512
# 2873245498288
